# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.13.1'

# %%
def get_list_midi(folder = 'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0/*/*.midi', seed_int = 666):
  """Get the list of all midi file in the folders
  
  Parameters
  ==========
  folder : str
    The midi folder.
  seed_int : int
    the random seed.
  
  Returns
  =======
  The midi files
  
  """
  list_all_midi = glob.glob(folder)
  seed(seed_int)
  shuffle(list_all_midi)
  return list_all_midi

list_all_midi = get_list_midi()

# %%
list_all_midi
# Out:
# ['C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_10_R1_2008_01-04_ORIG_MID--AUDIO_10_R1_2008_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_10_Track10_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_044_PIANO044_MID--AUDIO-split_07-06-17_Piano-e_1-04_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_17_R2_2008_01-04_ORIG_MID--AUDIO_17_R2_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_16_R1_2009_01-02_ORIG_MID--AUDIO_16_R1_2009_16_R1_2009_02_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_09_Track09_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_06_R1_2009_03-07_ORIG_MID--AUDIO_06_R1_2009_06_R1_2009_07_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_08_R1_2013_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_18_R2_2013_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_03_R1_2014_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_17_R1_2013_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_08_Track08_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_11_R1_2015_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_09_Track09_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_045_PIANO045_MID--AUDIO-split_07-06-17_Piano-e_2-01_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_054_PIANO054_MID--AUDIO-split_07-07-17_Piano-e_1-02_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_06_Track06_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_01_R1_2009_01-04_ORIG_MID--AUDIO_01_R1_2009_01_R1_2009_04_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_12_R2_2013_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_065_PIANO065_MID--AUDIO-split_07-07-17_Piano-e_3-01_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_05_Track05_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_08_R2_2015_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_16_R1_2014_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_10_R1_2006_01-04_ORIG_MID--AUDIO_10_R1_2006_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_11_R2_2015_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_19_R2_2013_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_10_Track10_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_16_R1_2015_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_11_R1_2013_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_062_PIANO062_MID--AUDIO-split_07-07-17_Piano-e_2-07_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_03_R1_2013_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_12_Track12_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_09_R1_2013_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_04_R1_2013_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_10_R1_2006_01-04_ORIG_MID--AUDIO_10_R1_2006_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_16_R1_2009_01-02_ORIG_MID--AUDIO_16_R1_2009_16_R1_2009_01_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_08_R1_2015_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_06_Track06_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_04_R1_2015_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_04_R2_2011_MID--AUDIO_R2-D2_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_11_R2_2008_01-05_ORIG_MID--AUDIO_11_R2_2008_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_20_R1_2006_01-04_ORIG_MID--AUDIO_20_R1_2006_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_02_R1_2011_MID--AUDIO_R1-D1_09_Track09_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_07_R2_2006_01_ORIG_MID--AUDIO_07_R2_2006_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_17_R2_2011_MID--AUDIO_R2-D5_06_Track06_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_20_R1_2011_MID--AUDIO_R1-D8_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_06_R1_2004_02-03_ORIG_MID--AUDIO_06_R1_2004_05_Track05_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_07_R1_2015_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_14_R1_2008_01-05_ORIG_MID--AUDIO_14_R1_2008_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_04-05_R1_2014_MID--AUDIO_04_R1_2014_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_06_Track06_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_11_R1_2006_01-06_ORIG_MID--AUDIO_11_R1_2006_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_20_R1_2009_06-07_ORIG_MID--AUDIO_20_R1_2009_20_R1_2009_06_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_047_PIANO047_MID--AUDIO-split_07-06-17_Piano-e_2-04_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_23_R3_2011_MID--AUDIO_R3-D8_05_Track05_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_14_Track14_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_07_Track07_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MID--AUDIO_16_R1_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_05_Track05_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_06_R2_2015_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_05_Track05_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_04_R1_2009_01-03_ORIG_MID--AUDIO_04_R1_2009_04_R1_2009_02_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_07_R3_2008_01-05_ORIG_MID--AUDIO_07_R3_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_06_R1_2015_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_09_R1_2015_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_21_R1_2014_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_08_R3_2008_01-05_ORIG_MID--AUDIO_08_R3_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_04-05_R1_2014_MID--AUDIO_05_R1_2014_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_08_Track08_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_10_R1_2009_03-05_ORIG_MID--AUDIO_10_R1_2009_10_R1_2009_04_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_047_PIANO047_MID--AUDIO-split_07-06-17_Piano-e_2-04_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_08_R2_2009_01_ORIG_MID--AUDIO_08_R2_2009_08_R2_2009_02_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_16_R1_2014_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_04_R2_2004_01_ORIG_MID--AUDIO_04_R2_2004_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_04_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_17_R2_2013_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_07_R2_2015_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_01_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_18_R1_2014_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_16_R1_2006_01-04_ORIG_MID--AUDIO_16_R1_2006_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_17_R1_2009_01-03_ORIG_MID--AUDIO_17_R1_2009_17_R1_2009_03_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_09_R2_2006_01_ORIG_MID--AUDIO_09_R2_2006_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_03_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_12_R1_2008_01-04_ORIG_MID--AUDIO_12_R1_2008_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_07_Track07_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_21_R1_2014_wav--6.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_05_Track05_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_056_PIANO056_MID--AUDIO-split_07-07-17_Piano-e_1-05_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_056_PIANO056_MID--AUDIO-split_07-07-17_Piano-e_1-05_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_06_Track06_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_11_R1_2015_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_059_PIANO059_MID--AUDIO-split_07-07-17_Piano-e_2-03_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_10_R1_2015_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_11_R1_2008_01-04_ORIG_MID--AUDIO_11_R1_2008_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_061_PIANO061_MID--AUDIO-split_07-07-17_Piano-e_2-05_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_19_R2_2013_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_05_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_09_R1_2006_01-04_ORIG_MID--AUDIO_09_R1_2006_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_07_R1_2014_wav--7.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_03_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_23_R2_2011_MID--AUDIO_R2-D6_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_058_PIANO058_MID--AUDIO-split_07-07-17_Piano-e_2-02_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_10_R1_2013_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_13_R1_2015_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_07_R1_2014_wav--6.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_054_PIANO054_MID--AUDIO-split_07-07-17_Piano-e_1-02_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_02_R3_2008_01-03_ORIG_MID--AUDIO_02_R3_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_06_Track06_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_042_PIANO042_MID--AUDIO-split_07-06-17_Piano-e_1-02_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_13_R2_2015_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_16_R2_2011_MID--AUDIO_R2-D4_08_Track08_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_01_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_080_PIANO080_MID--AUDIO-split_07-09-17_Piano-e_1-06_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_01_R1_2015_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1-D5_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_07_R1_2014_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_15_R1_2008_01-04_ORIG_MID--AUDIO_15_R1_2008_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_075_PIANO075_MID--AUDIO-split_07-08-17_Piano-e_2-06_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_067_PIANO067_MID--AUDIO-split_07-07-17_Piano-e_3-03_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_08_Track08_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_02_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_13_R1_2015_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_21_R2_2009_01_ORIG_MID--AUDIO_21_R2_2009_21_R2_2009_03_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_10_R2_2011_MID--AUDIO_R2-D3_10_Track10_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_02_R2_2013_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_18_R2_2013_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_17_R1_2013_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_18_Track18_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_16_Track16_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_03_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_058_PIANO058_MID--AUDIO-split_07-07-17_Piano-e_2-02_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_07_Track07_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_067_PIANO067_MID--AUDIO-split_07-07-17_Piano-e_3-03_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_15_R1_2015_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_17_R1_2011_MID--AUDIO_R1-D7_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_02_R2_2013_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_12_Track12_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_12_Track12_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_081_PIANO081_MID--AUDIO-split_07-09-17_Piano-e_2_-02_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_17_R1_2009_01-03_ORIG_MID--AUDIO_17_R1_2009_17_R1_2009_02_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_15_R1_2009_03-06_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_06_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_06_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_19-21_R3_2014_MID--AUDIO_21_R3_2014_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_21_R2_2015_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_21_R2_2015_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_03_R1_2009_01-02_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_02_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1-D5_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_08_R2_2013_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_23_R2_2011_MID--AUDIO_R2-D6_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_11_R2_2013_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_04-05_R1_2014_MID--AUDIO_05_R1_2014_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--6.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_08_R2_2009_01_ORIG_MID--AUDIO_08_R2_2009_08_R2_2009_04_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_22_R2_2015_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_16_R1_2015_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_23_R2_2006_01_ORIG_MID--AUDIO_23_R2_2006_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_08_Track08_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_055_PIANO055_MID--AUDIO-split_07-07-17_Piano-e_1-04_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_051_PIANO051_MID--AUDIO-split_07-06-17_Piano-e_3-02_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_10_R1_2004_03-04_ORIG_MID--AUDIO_10_R1_2004_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_12_R2_2011_MID--AUDIO_R2-D4_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_082_PIANO082_MID--AUDIO-split_07-09-17_Piano-e_2_-04_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_04_R1_2008_01-04_ORIG_MID--AUDIO_04_R1_2008_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_01_R1_2015_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_15_R1_2004_01-02_ORIG_MID--AUDIO_15_R1_2004_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_14_Track14_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_12_Track12_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_09_R2_2008_01-05_ORIG_MID--AUDIO_09_R2_2008_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_22_R2_2015_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_08_R1_2006_01-04_ORIG_MID--AUDIO_08_R1_2006_Disk1_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_08_R1_2004_03_ORIG_MID--AUDIO_08_R1_2004_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_01_R1_2013_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_04_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_18_R1_2014_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_04_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_25_R2_2011_MID--AUDIO_R2-D6_07_Track07_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_14_Track14_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_11_R1_2004_01-02_ORIG_MID--AUDIO_11_R1_2004_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_11_Track11_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_18_R1_2008_01-04_ORIG_MID--AUDIO_18_R1_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_052_PIANO052_MID--AUDIO-split_07-06-17_Piano-e_3-03_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_19-20_R1_2014_MID--AUDIO_20_R1_2014_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_03_R2_2011_MID--AUDIO_R2-D1_06_Track06_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_14_R1_2011_MID--AUDIO_R1-D6_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_08_R2_2014_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_15_R1_2015_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_14_R1_2006_01-05_ORIG_MID--AUDIO_14_R1_2006_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_070_PIANO070_MID--AUDIO-split_07-08-17_Piano-e_1-02_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_11_R1_2008_01-04_ORIG_MID--AUDIO_11_R1_2008_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_04-05_R1_2014_MID--AUDIO_05_R1_2014_wav--8.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_18_R3_2013_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_17_R1_2008_01-04_ORIG_MID--AUDIO_17_R1_2008_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_22_R2_2015_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG_MID--AUDIO_03_R1_2004_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_02_R1_2014_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_01_R1_2013_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_042_PIANO042_MID--AUDIO-split_07-06-17_Piano-e_1-02_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_078_PIANO078_MID--AUDIO-split_07-09-17_Piano-e_1-02_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_10_R1_2009_03-05_ORIG_MID--AUDIO_10_R1_2009_10_R1_2009_03_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1-D5_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_051_PIANO051_MID--AUDIO-split_07-06-17_Piano-e_3-02_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_09_R2_2008_01-05_ORIG_MID--AUDIO_09_R2_2008_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_18_R1_2013_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_02_R2_2011_MID--AUDIO_R2-D1_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_13_R1_2014_wav--6.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_056_PIANO056_MID--AUDIO-split_07-07-17_Piano-e_1-05_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_03_R1_2015_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MID--AUDIO_07_R1_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_09_R1_2013_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_06_Track06_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_06_WAV.midi',
# ...
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_14_R1_2011_MID--AUDIO_R1-D6_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_07_Track07_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_17_R1_2008_01-04_ORIG_MID--AUDIO_17_R1_2008_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_053_PIANO053_MID--AUDIO-split_07-06-17_Piano-e_3-04_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_10_R1_2011_MID--AUDIO_R1-D4_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_14_R1_2014_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_057_PIANO057_MID--AUDIO-split_07-07-17_Piano-e_1-07_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_02_R1_2014_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_08_R3_2013_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_15_R1_2008_01-04_ORIG_MID--AUDIO_15_R1_2008_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_09_Track09_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_06_R1_2015_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_05_R1_2013_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_04_R3_2014_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_12_R2_2008_01-04_ORIG_MID--AUDIO_12_R2_2008_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_10_Track10_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_SMF_17_R1_2004_04_ORIG_MID--AUDIO_17_R1_2004_09_Track09_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_070_PIANO070_MID--AUDIO-split_07-08-17_Piano-e_1-02_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_13_R1_2014_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_07_R2_2015_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_10_R2_2011_MID--AUDIO_R2-D3_11_Track11_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_05_R1_2013_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_15_R1_2009_01-02_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_02_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_21_R1_2009_01-03_ORIG_MID--AUDIO_21_R1_2009_21_R1_2009_01_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_08_R3_2013_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_04-05_R1_2014_MID--AUDIO_04_R1_2014_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_10_R2_2009_01_ORIG_MID--AUDIO_10_R2_2009_10_R2_2009_02_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_050_PIANO050_MID--AUDIO-split_07-06-17_Piano-e_3-01_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_082_PIANO082_MID--AUDIO-split_07-09-17_Piano-e_2_-04_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_21_R1_2014_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_09_R1_2009_05-06_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_05_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_13_Track13_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_08_R2_2015_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_04_R3_2014_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_04-05_R1_2014_MID--AUDIO_05_R1_2014_wav--7.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_06_R1_2006_01-04_ORIG_MID--AUDIO_06_R1_2006_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_06_R2_2008_01-05_ORIG_MID--AUDIO_06_R2_2008_wav--5.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_04_R2_2004_01_ORIG_MID--AUDIO_04_R2_2004_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_06_Track06_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_15_R1_2004_03_ORIG_MID--AUDIO_15_R1_2004_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_18_R1_2008_01-04_ORIG_MID--AUDIO_18_R1_2008_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_067_PIANO067_MID--AUDIO-split_07-07-17_Piano-e_3-03_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_14_R1_2006_01-05_ORIG_MID--AUDIO_14_R1_2006_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_13_Track13_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_09_R2_2011_MID--AUDIO_R2-D3_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_03_Track03_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_23_R1_2006_01-05_ORIG_MID--AUDIO_23_R1_2006_02_Track02_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_057_PIANO057_MID--AUDIO-split_07-07-17_Piano-e_1-07_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_12_R2_2008_01-04_ORIG_MID--AUDIO_12_R2_2008_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2015\\MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_18_R1_2015_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_11_R3_2008_01-04_ORIG_MID--AUDIO_11_R3_2008_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_044_PIANO044_MID--AUDIO-split_07-06-17_Piano-e_1-04_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_17_R3_2013_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_10_R1_2013_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_12_R2_2013_wav--3.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--2.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_07_R2_2006_01_ORIG_MID--AUDIO_07_R2_2006_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_16_R1_2013_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_16_R1_2009_03-06_ORIG_MID--AUDIO_16_R1_2009_16_R1_2009_03_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_11_R1_2006_01-06_ORIG_MID--AUDIO_11_R1_2006_01_Track01_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_053_PIANO053_MID--AUDIO-split_07-06-17_Piano-e_3-04_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_03_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2014\\MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_18_R1_2014_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2017\\MIDI-Unprocessed_081_PIANO081_MID--AUDIO-split_07-09-17_Piano-e_2_-02_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_12_R1_2009_03-05_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_05_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_17_R1_2013_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_17_R1_2009_04_ORIG_MID--AUDIO_17_R1_2009_17_R1_2009_04_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2011\\MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_07_Track07_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2004\\MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_06_Track06_wav.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2008\\MIDI-Unprocessed_14_R1_2008_01-05_ORIG_MID--AUDIO_14_R1_2008_wav--4.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2013\\ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_04_R2_2013_wav--1.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2009\\MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_03_WAV.midi',
#  'C:/Users/VISHESH/Desktop/cs/7th sem/AI/New folder/maestro-v1.0.0-midi/maestro-v1.0.0\\2006\\MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_01_Track01_wav.midi',
#  ...]

# %%
class NoteTokenizer:
    
    def __init__(self):
      self.notes_to_index = {}
      self.index_to_notes = {}
      self.num_of_word = 0
      self.unique_word = 0
      self.notes_freq = {}
        
    def transform(self,list_array):
      """ Transform a list of note in string into index.
      
      Parameters
      ==========
      list_array : list
        list of note in string format
      
      Returns
      =======
      The transformed list in numpy array.
      
      """
      transformed_list = []
      for instance in list_array:
          transformed_list.append([self.notes_to_index[note] for note in instance])
      return np.array(transformed_list, dtype=np.int32)
 
    def partial_fit(self, notes):
        """ Partial fit on the dictionary of the tokenizer
        
        Parameters
        ==========
        notes : list of notes
        
        """
        for note in notes:
            note_str = ','.join(str(a) for a in note)
            if note_str in self.notes_freq:
                self.notes_freq[note_str] += 1
                self.num_of_word += 1
            else:
                self.notes_freq[note_str] = 1
                self.unique_word += 1
                self.num_of_word += 1
                self.notes_to_index[note_str], self.index_to_notes[self.unique_word] = self.unique_word, note_str
            
    def add_new_note(self, note):
        """ Add a new note into the dictionary

        Parameters
        ==========
        note : str
          a new note who is not in dictionary.  

        """
        assert note not in self.notes_to_index
        self.unique_word += 1
        self.notes_to_index[note], self.index_to_notes[self.unique_word] = self.unique_word, note
        
def generate_batch_song(list_all_midi, batch_music=16, start_index=0, fs=30, seq_len=50, use_tqdm=False):
    """
    Generate Batch music that will be used to be input and output of the neural network
    
    Parameters
    ==========
    list_all_midi : list
      List of midi files
    batch_music : int
      A number of music in one batch
    start_index : int
      The start index to be batched in list_all_midi
    fs : int
      Sampling frequency of the columns, i.e. each column is spaced apart
        by ``1./fs`` seconds.
    seq_len : int
      The sequence length of the music to be input of neural network
    use_tqdm : bool
      Whether to use tqdm or not in the function
    
    Returns
    =======
    Tuple of input and target neural network
    
    """
    
    assert len(list_all_midi) >= batch_music
    dict_time_notes = generate_dict_time_notes(list_all_midi, batch_music, start_index, fs, use_tqdm=use_tqdm)
    
    list_musics = process_notes_in_song(dict_time_notes, seq_len)
    collected_list_input, collected_list_target = [], []
     
    for music in list_musics:
        list_training, list_target = generate_input_and_target(music, seq_len)
        collected_list_input += list_training
        collected_list_target += list_target
    return collected_list_input, collected_list_target

def generate_dict_time_notes(list_all_midi, batch_song = 16, start_index=0, fs=30, use_tqdm=True):
    """ Generate map (dictionary) of music ( in index ) to piano_roll (in np.array)

    Parameters
    ==========
    list_all_midi : list
        List of midi files
    batch_music : int
      A number of music in one batch
    start_index : int
      The start index to be batched in list_all_midi
    fs : int
      Sampling frequency of the columns, i.e. each column is spaced apart
        by ``1./fs`` seconds.
    use_tqdm : bool
      Whether to use tqdm or not in the function

    Returns
    =======
    dictionary of music to piano_roll (in np.array)

    """
    assert len(list_all_midi) >= batch_song
    
    dict_time_notes = {}
    process_tqdm_midi = tqdm_notebook(range(start_index, min(start_index + batch_song, len(list_all_midi)))) if use_tqdm else range(start_index,  min(start_index + batch_song, len(list_all_midi)))
    for i in process_tqdm_midi:
        midi_file_name = list_all_midi[i]
        if use_tqdm:
            process_tqdm_midi.set_description("Processing {}".format(midi_file_name))
        try: # Handle exception on malformat MIDI files
            midi_pretty_format = pretty_midi.PrettyMIDI(midi_file_name)
            piano_midi = midi_pretty_format.instruments[0] # Get the piano channels
            piano_roll = piano_midi.get_piano_roll(fs=fs)
            dict_time_notes[i] = piano_roll
        except Exception as e:
            print(e)
            print("broken file : {}".format(midi_file_name))
            pass
    return dict_time_notes

def generate_input_and_target(dict_keys_time, seq_len=50):
    """ Generate input and the target of our deep learning for one music.
    
    Parameters
    ==========
    dict_keys_time : dict
      Dictionary of timestep and notes
    seq_len : int
      The length of the sequence
      
    Returns
    =======
    Tuple of list of input and list of target of neural network.
    
       
    """
    # Get the start time and end time
    start_time, end_time = list(dict_keys_time.keys())[0], list(dict_keys_time.keys())[-1]
    list_training, list_target = [], []
    for index_enum, time in enumerate(range(start_time, end_time)):
        list_append_training, list_append_target = [], []
        start_iterate = 0
        flag_target_append = False # flag to append the test list
        if index_enum < seq_len:
            start_iterate = seq_len - index_enum - 1
            for i in range(start_iterate): # add 'e' to the seq list. 
                list_append_training.append('e')
                flag_target_append = True

        for i in range(start_iterate,seq_len):
            index_enum = time - (seq_len - i - 1)
            if index_enum in dict_keys_time:
                list_append_training.append(','.join(str(x) for x in dict_keys_time[index_enum]))      
            else:
                list_append_training.append('e')

        # add time + 1 to the list_append_target
        if time+1 in dict_keys_time:
            list_append_target.append(','.join(str(x) for x in dict_keys_time[time+1]))
        else:
            list_append_target.append('e')
        list_training.append(list_append_training)
        list_target.append(list_append_target)
    return list_training, list_target

def process_notes_in_song(dict_time_notes, seq_len = 50):
    """
    Iterate the dict of piano rolls into dictionary of timesteps and note played
    
    Parameters
    ==========
    dict_time_notes : dict
      dict contains index of music ( in index ) to piano_roll (in np.array)
    seq_len : int
      Length of the sequence
      
    Returns
    =======
    Dict of timesteps and note played
    """
    list_of_dict_keys_time = []
    
    for key in dict_time_notes:
        sample = dict_time_notes[key]
        times = np.unique(np.where(sample > 0)[1])
        index = np.where(sample > 0)
        dict_keys_time = {}

        for time in times:
            index_where = np.where(index[1] == time)
            notes = index[0][index_where]
            dict_keys_time[time] = notes
        list_of_dict_keys_time.append(dict_keys_time)
    return list_of_dict_keys_time

# %%
sampled_200_midi = list_all_midi[0:100]

# %%
batch = 1
start_index = 0
note_tokenizer = NoteTokenizer()

for i in tqdm_notebook(range(len(sampled_200_midi))):
    dict_time_notes = generate_dict_time_notes(sampled_200_midi, batch_song=1, start_index=i, use_tqdm=False, fs=5)
    full_notes = process_notes_in_song(dict_time_notes)
    for note in full_notes:
        note_tokenizer.partial_fit(list(note.values()))
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
note_tokenizer.add_new_note('e') # Add empty notes

# %%
unique_notes = note_tokenizer.unique_word
print(unique_notes)
# Out:
# 34221

# %%
seq_len = 50
EPOCHS = 1
BATCH_SONG = 16
BATCH_NNET_SIZE = 96
TOTAL_SONGS = len(sampled_200_midi)
FRAME_PER_SECOND = 5

# %%
class SeqSelfAttention(tf.keras.layers.Layer):

    ATTENTION_TYPE_ADD = 'additive'
    ATTENTION_TYPE_MUL = 'multiplicative'

    def __init__(self,
                 units=32,
                 attention_width=None,
                 attention_type=ATTENTION_TYPE_ADD,
                 return_attention=False,
                 history_only=False,
                 kernel_initializer='glorot_normal',
                 bias_initializer='zeros',
                 kernel_regularizer=None,
                 bias_regularizer=None,
                 kernel_constraint=None,
                 bias_constraint=None,
                 use_additive_bias=True,
                 use_attention_bias=True,
                 attention_activation=None,
                 attention_regularizer_weight=0.0,
                 **kwargs):
        """Layer initialization.
        For additive attention, see: https://arxiv.org/pdf/1806.01264.pdf
        :param units: The dimension of the vectors that used to calculate the attention weights.
        :param attention_width: The width of local attention.
        :param attention_type: 'additive' or 'multiplicative'.
        :param return_attention: Whether to return the attention weights for visualization.
        :param history_only: Only use historical pieces of data.
        :param kernel_initializer: The initializer for weight matrices.
        :param bias_initializer: The initializer for biases.
        :param kernel_regularizer: The regularization for weight matrices.
        :param bias_regularizer: The regularization for biases.
        :param kernel_constraint: The constraint for weight matrices.
        :param bias_constraint: The constraint for biases.
        :param use_additive_bias: Whether to use bias while calculating the relevance of inputs features
                                  in additive mode.
        :param use_attention_bias: Whether to use bias while calculating the weights of attention.
        :param attention_activation: The activation used for calculating the weights of attention.
        :param attention_regularizer_weight: The weights of attention regularizer.
        :param kwargs: Parameters for parent class.
        """
        self.supports_masking = True
        self.units = units
        self.attention_width = attention_width
        self.attention_type = attention_type
        self.return_attention = return_attention
        self.history_only = history_only
        if history_only and attention_width is None:
            self.attention_width = int(1e9)

        self.use_additive_bias = use_additive_bias
        self.use_attention_bias = use_attention_bias
        self.kernel_initializer = tf.keras.initializers.get(kernel_initializer)
        self.bias_initializer = tf.keras.initializers.get(bias_initializer)
        self.kernel_regularizer = tf.keras.regularizers.get(kernel_regularizer)
        self.bias_regularizer = tf.keras.regularizers.get(bias_regularizer)
        self.kernel_constraint = tf.keras.constraints.get(kernel_constraint)
        self.bias_constraint = tf.keras.constraints.get(bias_constraint)
        self.attention_activation = tf.keras.activations.get(attention_activation)
        self.attention_regularizer_weight = attention_regularizer_weight
        self._backend = tf.keras.backend.backend()

        if attention_type == SeqSelfAttention.ATTENTION_TYPE_ADD:
            self.Wx, self.Wt, self.bh = None, None, None
            self.Wa, self.ba = None, None
        elif attention_type == SeqSelfAttention.ATTENTION_TYPE_MUL:
            self.Wa, self.ba = None, None
        else:
            raise NotImplementedError('No implementation for attention type : ' + attention_type)

        super(SeqSelfAttention, self).__init__(**kwargs)

    def get_config(self):
        config = {
            'units': self.units,
            'attention_width': self.attention_width,
            'attention_type': self.attention_type,
            'return_attention': self.return_attention,
            'history_only': self.history_only,
            'use_additive_bias': self.use_additive_bias,
            'use_attention_bias': self.use_attention_bias,
            'kernel_initializer': tf.keras.regularizers.serialize(self.kernel_initializer),
            'bias_initializer': tf.keras.regularizers.serialize(self.bias_initializer),
            'kernel_regularizer': tf.keras.regularizers.serialize(self.kernel_regularizer),
            'bias_regularizer': tf.keras.regularizers.serialize(self.bias_regularizer),
            'kernel_constraint': tf.keras.constraints.serialize(self.kernel_constraint),
            'bias_constraint': tf.keras.constraints.serialize(self.bias_constraint),
            'attention_activation': tf.keras.activations.serialize(self.attention_activation),
            'attention_regularizer_weight': self.attention_regularizer_weight,
        }
        base_config = super(SeqSelfAttention, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

    def build(self, input_shape):
        if isinstance(input_shape, list):
            input_shape = input_shape[0]
        if self.attention_type == SeqSelfAttention.ATTENTION_TYPE_ADD:
            self._build_additive_attention(input_shape)
        elif self.attention_type == SeqSelfAttention.ATTENTION_TYPE_MUL:
            self._build_multiplicative_attention(input_shape)
        super(SeqSelfAttention, self).build(input_shape)

    def _build_additive_attention(self, input_shape):
        feature_dim = input_shape[2]

        self.Wt = self.add_weight(shape=(feature_dim, self.units),
                                  name='{}_Add_Wt'.format(self.name),
                                  initializer=self.kernel_initializer,
                                  regularizer=self.kernel_regularizer,
                                  constraint=self.kernel_constraint)
        self.Wx = self.add_weight(shape=(feature_dim, self.units),
                                  name='{}_Add_Wx'.format(self.name),
                                  initializer=self.kernel_initializer,
                                  regularizer=self.kernel_regularizer,
                                  constraint=self.kernel_constraint)
        if self.use_additive_bias:
            self.bh = self.add_weight(shape=(self.units,),
                                      name='{}_Add_bh'.format(self.name),
                                      initializer=self.bias_initializer,
                                      regularizer=self.bias_regularizer,
                                      constraint=self.bias_constraint)

        self.Wa = self.add_weight(shape=(self.units, 1),
                                  name='{}_Add_Wa'.format(self.name),
                                  initializer=self.kernel_initializer,
                                  regularizer=self.kernel_regularizer,
                                  constraint=self.kernel_constraint)
        if self.use_attention_bias:
            self.ba = self.add_weight(shape=(1,),
                                      name='{}_Add_ba'.format(self.name),
                                      initializer=self.bias_initializer,
                                      regularizer=self.bias_regularizer,
                                      constraint=self.bias_constraint)

    def _build_multiplicative_attention(self, input_shape):
        feature_dim = input_shape[2]

        self.Wa = self.add_weight(shape=(feature_dim, feature_dim),
                                  name='{}_Mul_Wa'.format(self.name),
                                  initializer=self.kernel_initializer,
                                  regularizer=self.kernel_regularizer,
                                  constraint=self.kernel_constraint)
        if self.use_attention_bias:
            self.ba = self.add_weight(shape=(1,),
                                      name='{}_Mul_ba'.format(self.name),
                                      initializer=self.bias_initializer,
                                      regularizer=self.bias_regularizer,
                                      constraint=self.bias_constraint)

    def call(self, inputs, mask=None, **kwargs):
        if isinstance(inputs, list):
            inputs, positions = inputs
            positions = K.cast(positions, 'int32')
            mask = mask[1]
        else:
            positions = None

        input_len = K.shape(inputs)[1]

        if self.attention_type == SeqSelfAttention.ATTENTION_TYPE_ADD:
            e = self._call_additive_emission(inputs)
        elif self.attention_type == SeqSelfAttention.ATTENTION_TYPE_MUL:
            e = self._call_multiplicative_emission(inputs)

        if self.attention_activation is not None:
            e = self.attention_activation(e)
        e = K.exp(e - K.max(e, axis=-1, keepdims=True))
        if self.attention_width is not None:
            ones = tf.ones((input_len, input_len))
            if self.history_only:
                local = tf.linalg.band_part(
                    ones,
                    K.minimum(input_len, self.attention_width - 1),
                    0,
                )
            else:
                local = tf.linalg.band_part(
                    ones,
                    K.minimum(input_len, self.attention_width // 2),
                    K.minimum(input_len, (self.attention_width - 1) // 2),
                )
            e = e * K.expand_dims(local, 0)
        if mask is not None:
            mask = K.cast(mask, K.floatx())
            mask = K.expand_dims(mask)
            e = K.permute_dimensions(K.permute_dimensions(e * mask, (0, 2, 1)) * mask, (0, 2, 1))

        # a_{t} = \text{softmax}(e_t)
        s = K.sum(e, axis=-1)
        s = K.tile(K.expand_dims(s, axis=-1), K.stack([1, 1, input_len]))
        a = e / (s + K.epsilon())

        # l_t = \sum_{t'} a_{t, t'} x_{t'}
        v = K.batch_dot(a, inputs)
        if self.attention_regularizer_weight > 0.0:
            self.add_loss(self._attention_regularizer(a))

        if positions is not None:
            pos_num = K.shape(positions)[1]
            batch_indices = K.tile(K.expand_dims(K.arange(K.shape(inputs)[0]), axis=-1), K.stack([1, pos_num]))
            pos_indices = K.stack([batch_indices, positions], axis=-1)
            v = tf.gather_nd(v, pos_indices)
            a = tf.gather_nd(a, pos_indices)

        if self.return_attention:
            return [v, a]
        return v

    def _call_additive_emission(self, inputs):
        input_shape = K.shape(inputs)
        batch_size, input_len = input_shape[0], input_shape[1]

        # h_{t, t'} = \tanh(x_t^T W_t + x_{t'}^T W_x + b_h)
        q, k = K.dot(inputs, self.Wt), K.dot(inputs, self.Wx)
        q = K.tile(K.expand_dims(q, 2), K.stack([1, 1, input_len, 1]))
        k = K.tile(K.expand_dims(k, 1), K.stack([1, input_len, 1, 1]))
        if self.use_additive_bias:
            h = K.tanh(q + k + self.bh)
        else:
            h = K.tanh(q + k)

        # e_{t, t'} = W_a h_{t, t'} + b_a
        if self.use_attention_bias:
            e = K.reshape(K.dot(h, self.Wa) + self.ba, (batch_size, input_len, input_len))
        else:
            e = K.reshape(K.dot(h, self.Wa), (batch_size, input_len, input_len))
        return e

    def _call_multiplicative_emission(self, inputs):
        # e_{t, t'} = x_t^T W_a x_{t'} + b_a
        e = K.batch_dot(K.dot(inputs, self.Wa), K.permute_dimensions(inputs, (0, 2, 1)))
        if self.use_attention_bias:
            e = e + self.ba
        return e

    def compute_output_shape(self, input_shape):
        if isinstance(input_shape, list):
            input_shape, pos_shape = input_shape
            output_shape = (input_shape[0], pos_shape[1], input_shape[2])
        else:
            output_shape = input_shape
        if self.return_attention:
            attention_shape = (input_shape[0], output_shape[1], input_shape[1])
            return [output_shape, attention_shape]
        return output_shape

    def compute_mask(self, inputs, mask=None):
        if isinstance(inputs, list):
            mask = mask[1]
        if self.return_attention:
            return [mask, None]
        return mask

    def _attention_regularizer(self, attention):
        batch_size = K.cast(K.shape(attention)[0], K.floatx())
        input_len = K.shape(attention)[-1]
        return self.attention_regularizer_weight * K.sum(K.square(K.batch_dot(
            attention,
            K.permute_dimensions(attention, (0, 2, 1))) - tf.eye(input_len))) / batch_size

    @staticmethod
    def get_custom_objects():
      return {'SeqSelfAttention': SeqSelfAttention}

# %%
def create_model(seq_len, unique_notes, dropout=0.3, output_emb=100, rnn_unit=128, dense_unit=64):
  inputs = tf.keras.layers.Input(shape=(seq_len,))
  embedding = tf.keras.layers.Embedding(input_dim=unique_notes+1, output_dim=output_emb, input_length=seq_len)(inputs)
  forward_pass = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(rnn_unit, return_sequences=True))(embedding)
  forward_pass , att_vector = SeqSelfAttention(
       return_attention=True, attention_width=50,)(forward_pass)
#       #attention_activation='sigmoid', 
#       #attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
#       attention_width=50, 
#       #kernel_regularizer=tf.keras.regularizers.l2(1e-4),
#       #bias_regularizer=tf.keras.regularizers.l1(1e-4),
#       #attention_regularizer_weight=1e-4,
#       )(forward_pass)
#   forward_pass = tf.keras.layers.Dropout(dropout)(forward_pass)
#   forward_pass = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(rnn_unit, return_sequences=True))(forward_pass)
#   forward_pass , att_vector2 = SeqSelfAttention(
#       return_attention=True,
#       attention_activation='sigmoid', 
#       attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
#       attention_width=50, 
#       kernel_regularizer=tf.keras.regularizers.l2(1e-4),
#       bias_regularizer=tf.keras.regularizers.l1(1e-4),
#       attention_regularizer_weight=1e-4,
#       )(forward_pass)
#   forward_pass = tf.keras.layers.Dropout(dropout)(forward_pass)
#   forward_pass = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(rnn_unit))(forward_pass)
  forward_pass = tf.keras.layers.Dropout(dropout)(forward_pass)
  forward_pass = tf.keras.layers.Dense(dense_unit)(forward_pass)
  forward_pass = tf.keras.layers.LeakyReLU()(forward_pass)
  outputs = tf.keras.layers.Dense(unique_notes+1, activation = "softmax")(forward_pass)

  model = tf.keras.Model(inputs=inputs, outputs=outputs, name='generate_scores_rnn')
  return model

model = create_model(seq_len, unique_notes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-7ab7f5eb4ba3> in <module>
#      33   return model
#      34
# ---> 35 model = create_model(seq_len, unique_notes)
#
# <ipython-input-64-7ab7f5eb4ba3> in create_model(seq_len, unique_notes, dropout, output_emb, rnn_unit, dense_unit)
#       4   forward_pass = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(rnn_unit, return_sequences=True))(embedding)
#       5   forward_pass , att_vector = SeqSelfAttention(
# ----> 6        return_attention=True, attention_width=50,)(forward_pass)
#       7 #       #attention_activation='sigmoid',
#       8 #       #attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     536     """
#     537     input_list = nest.flatten(inputs)
# --> 538     # Accept NumPy inputs by converting to Tensors.
#     539     if any(isinstance(x, (np.ndarray, float, int)) for x in input_list):
#     540       # Don't call `ops.convert_to_tensor` on all `inputs` because
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _maybe_build(self, inputs)
#    1601       for argument_name in all_args:
#    1602         if argument_name in keyword_arg_names:
# -> 1603           remaining_args_are_keyword = True
#    1604         else:
#    1605           if remaining_args_are_keyword:
#
# <ipython-input-60-a96767bbb595> in build(self, input_shape)
#      97             input_shape = input_shape[0]
#      98         if self.attention_type == SeqSelfAttention.ATTENTION_TYPE_ADD:
# ---> 99             self._build_additive_attention(input_shape)
#     100         elif self.attention_type == SeqSelfAttention.ATTENTION_TYPE_MUL:
#     101             self._build_multiplicative_attention(input_shape)
#
# <ipython-input-60-a96767bbb595> in _build_additive_attention(self, input_shape)
#     109                                   initializer=self.kernel_initializer,
#     110                                   regularizer=self.kernel_regularizer,
# --> 111                                   constraint=self.kernel_constraint)
#     112         self.Wx = self.add_weight(shape=(feature_dim, self.units),
#     113                                   name='{}_Add_Wx'.format(self.name),
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     347     # Initialize variable when no initializer provided
#     348     if initializer is None:
# --> 349       # If dtype is DT_FLOAT, provide a uniform unit scaling initializer
#     350       if dtype.is_floating:
#     351         initializer = initializers.glorot_uniform()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\checkpointable\base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     605     new_variable = getter(
#     606         name=name, shape=shape, dtype=dtype, initializer=initializer,
# --> 607         **kwargs_for_getter)
#     608
#     609     # If we set an initializer and the variable processed it, tracking will not
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_utils.py in make_variable(name, shape, dtype, initializer, partition_info, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     143       name=name,
#     144       trainable=trainable,
# --> 145       caching_device=caching_device,
#     146       dtype=variable_dtype,
#     147       validate_shape=validate_shape,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     211     if cls is VariableV1:
#     212       return cls._variable_v1_call(*args, **kwargs)
# --> 213     elif cls is Variable:
#     214       return cls._variable_v2_call(*args, **kwargs)
#     215     else:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation)
#     174         synchronization=synchronization,
#     175         aggregation=aggregation)
# --> 176
#     177   def _variable_v2_call(cls,
#     178                         initial_value=None,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in <lambda>(**kwargs)
#     153     """Call on Variable class. Useful to force the signature."""
#     154     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
# --> 155     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     156       previous_getter = _make_getter(getter, previous_getter)
#     157
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in default_variable_creator(next_creator, **kwargs)
#    2486     distribute_strategy = kwargs.get("distribute_strategy", None)
#    2487     return resource_variable_ops.ResourceVariable(
# -> 2488         initial_value=initial_value, trainable=trainable,
#    2489         collections=collections, validate_shape=validate_shape,
#    2490         caching_device=caching_device, name=name, dtype=dtype,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     215     else:
#     216       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
# --> 217
#     218
#     219 @tf_export("Variable", v1=[])
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint)
#     292
#     293   See the [Variables How To](https://tensorflow.org/guide/variables)
# --> 294   for a high level overview.
#     295
#     296   A `ResourceVariable` allows you to maintain state across subsequent calls to
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, constraint)
#     404     """
#     405     self._distribute_strategy = distribute_strategy
# --> 406     if variable_def:
#     407       if initial_value is not None:
#     408         raise ValueError("variable_def and initial_value are mutually "
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_utils.py in <lambda>()
#     125     if initializing_from_value:
#     126       init_val = initializer
# --> 127       variable_dtype = None
#     128     else:
#     129       # Instantiate initializer if provided initializer is a type object.
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py in __call__(self, shape, dtype, partition_info)
#     497       None,
#     498       "`normal` is a deprecated alias for `truncated_normal`",
# --> 499       distribution="normal")
#     500   def __init__(self,
#     501                scale=1.0,
#
# TypeError: unsupported operand type(s) for /: 'Dimension' and 'float'
